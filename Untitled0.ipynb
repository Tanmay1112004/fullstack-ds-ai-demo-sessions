# %%
9
# Out:
# 9

# %%
9 + 9
# Out:
# 18

# %%
9 + 9 - (10 * 3) - 3
# Out:
# -15

# %%
9 + 9 - 10 * 3 - 3
# Out:
# -15

# %% [markdown]
# 9,9,10,3,3 = operators
# +,-,*,/ = operands

# %%
# numbers are called as operands
# +, -, *, / are called as operators

# %%
# Arithmatic Operators

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 * 2 # multiplication
# Out:
# 20

# %%
10 ** 2 # power
# Out:
# 100

# %%
10 / 5 # float division
# Out:
# 2.0

# %%
10 // 5 # int division
# Out:
# 2

# %%
10 % 5
# Out:
# 0

# %%
# Assignment operators

# %%
 x = 10
 x
 # X is called object, variable, identifier
# Out:
# 10

# %%
x + 2
# Out:
# 12

# %%
x + 2
# Out:
# 12

# %%
x + 2
# Out:
# 12

# %%
x += 12
x
# Out:
# 46

# %%
x -= 12
x
# Out:
# 32

# %%
x = 12
x
# Out:
# 12

# %%
x *= 2
x
# Out:
# 24

# %%
x *= 2
x
# Out:
# 48

# %%
x /=2
x
# Out:
# 24.0

# %%
x //=2
x
# Out:
# 12.0

# %%
# Unary Operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
# String in Python

# %%
'Tanmay'
# Out:
# 'Tanmay'

# %%
a = 5
b = 6
c = a + b
c
# Out:
# 11

# %%
s = 'Python'
s
# Out:
# 'Python'

# %%
s[0:5]
s
# Out:
# 'Pytho'

# %%
s[0:6]
s
# Out:
# 'Python'
